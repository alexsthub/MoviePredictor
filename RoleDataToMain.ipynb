# %%
import pandas as pd
import numpy as np

# %%
#Read in main movie data and actor data
#TODO: remove 0:4 when doing this for real USE COPY!!!!!!
mainData = pd.read_csv('cleanData.csv')
#actorData = pd.read_csv('actors.csv')
#directorData = pd.read_csv('directors.csv')

allActors = pd.ExcelFile('actorsText.xlsx')
#allActors.to_csv('allActorsWithData.csv', index = False)
allActors = allActors.parse("Sheet1")

allDirectors = pd.ExcelFile('directors.xlsx')
allDirectors = allDirectors.parse("Sheet1")

mainDataLen = len(mainData)

positiveProfitLen = len(mainData.loc[mainData['profit'] > 0])


positiveProfitLen / mainDataLen
# Out:
# 0.6580877066858375

# %%
#write a function so it can work for both actors and directors
def addRoleData (mainData, namesData, role):
    newDataFrameColumns = []
    if role == "actor": 
        for movie in mainData.itertuples():
            actors = movie.actors
            print(actors)
            #actors = actors.split(", ")
            #actorCount = len(actors)
            totalPreviousMovies = 0
            totalNominations = 0
            totalWins = 0
            for actor in actors:
                actorIndex = namesData.loc[namesData['actorName']==actor].index[0]
                previousMovies = namesData.loc[actorIndex, 'actorMovieCount']
                nominations = namesData.loc[actorIndex, 'actorAwardNominations']
                wins = namesData.loc[actorIndex, 'actorAwardWins']        
                totalPreviousMovies += previousMovies
                totalNominations += nominations
                totalWins += wins
            averagePreviousMovies = round(totalPreviousMovies / actorCount, 2)
            averageNominations = round(totalNominations / actorCount, 2)
            averageWins = round(totalWins / actorCount, 2)
            newDataFrameColumns.append({'averageActorMovies': averagePreviousMovies,
                                        'averageActorAwardNominations': averageNominations,
                                        'averageActorAwardWins': averageWins})
        newDataFrameColumns = pd.DataFrame(newDataFrameColumns, columns = ['averageActorMovies', 
                                                                            'averageActorAwardNominations',
                                                                            'averageActorAwardWins'])
    else:
        for movie in mainData.itertuples():
            directors = movie.director
            directors = directors.split(", ")
            directorCount = len(directors)
            totalPreviousMovies = 0
            totalNominations = 0
            totalWins = 0
            for director in directors:
                directorIndex = directorData.loc[directorData['directorName']==director].index[0]
                previousMovies = directorData.loc[directorIndex, 'directorMovieCount']
                nominations = directorData.loc[directorIndex, 'directorAwardNominations']
                wins = directorData.loc[directorIndex, 'directorAwardWins']        
                totalPreviousMovies += previousMovies
                totalNominations += nominations
                totalWins += wins
            averagePreviousMovies = round(totalPreviousMovies / directorCount, 2)
            averageNominations = round(totalNominations / directorCount, 2)
            averageWins = round(totalWins / directorCount, 2)
            newDataFrameColumns.append({'averageDirectorMovies': averagePreviousMovies,
                                        'averageDirectorAwardNominations': averageNominations,
                                        'averageDirectorAwardWins': averageWins})
        newDataFrameColumns = pd.DataFrame(newDataFrameColumns, columns = ['averageDirectorMovies', 
                                                                            'averageDirectorAwardNominations',
                                                                            'averageDirectorAwardWins'])
    combinedDataFrame = pd.concat([mainData,newDataFrameColumns], axis=1)
    return combinedDataFrame

# %%
#raw for just actors: can remove when confident rest works
newDataFrameColumns = []
for movie in mainData.itertuples() :
    actor = movie.actors
    #print(actor)
    #actors = actors.split(", ")
    #print(actors)
    #actorCount = len(actors)
    totalPreviousMovies = 0
    totalNominations = 0
    totalWins = 0
    #for actor in actors:
    #print(actor)
    #actor.encode('ISO-8859-1')
    try:
        actorIndex = allActors.loc[allActors['actorName']==actor].index[0]
        previousMovies = allActors.loc[actorIndex, 'actorMovieCount']
        nominations = allActors.loc[actorIndex, 'actorAwardNominations']
        wins = allActors.loc[actorIndex, 'actorAwardWins']
        totalPreviousMovies += previousMovies
        totalNominations += nominations
        totalWins += wins
        #print(averagePreviousMovies, averageNominations, averageWins)
        newDataFrameColumns.append({'actorMovies': totalPreviousMovies,
                                    'actorAwardNominations': totalNominations,
                                    'actorAwardWins': totalWins})
    #when movie doesnt have an actor 
    except: 
        newDataFrameColumns.append({'actorMovies': 1,
                                    'actorAwardNominations': 0,
                                    'actorAwardWins': 0})
#newDataFrameColumns = pd.DataFrame(newDataFrameColumns, columns = ['averageActorMovies', 'averageActorAwardNominations',
                                                     #'averageActorAwardWins'] )


#write as csv
#newDataFrameColumns

# %%
#newDataFrame = addRoleData(mainData, allActors, "actor")
#TODO: Do with directorData
#newDataFrame = addRoleData(newDataFrame, directorData, "director")
newDataFrameColumns2 = [] 
for movie in mainData.itertuples() :
    director = movie.director;
    totalPreviousMovies = 0
    totalNominations = 0
    totalWins = 0
    try:
        directorIndex = allDirectors.loc[allDirectors['directorName']==director].index[0]
        previousMovies = allDirectors.loc[directorIndex, 'directorMovieCount']
        nominations = allDirectors.loc[directorIndex, 'directorAwardNominations']
        wins = allDirectors.loc[directorIndex, 'directorAwardWins']
        totalPreviousMovies += previousMovies
        totalNominations += nominations
        totalWins += wins
        newDataFrameColumns2.append({'directorMovies': totalPreviousMovies,
                                    'directorAwardNominations': totalNominations,
                                    'directorAwardWins': totalWins})
    #when movie doesnt have an director 
    except: 
        newDataFrameColumns2.append({'directorMovies': 1,
                                    'directorAwardNominations': 0,
                                    'directorAwardWins': 0})

# %%
# Out:
#               title original_title   budget   revenue     profit  success  \
# 721   Seven Samurai           七人の侍  2000000  271841.0 -1728159.0        0
# 1782       Rashomon            羅生門   250000   96568.0  -153432.0        0
#
#       belongs_to_collection  count_language  runtime   genre  genre_encode  \
# 721                       0               1    207.0  Action             0
# 1782                      0               1     88.0   Crime             4
#
#                    genres release_date        director          actors
# 721          Action,Drama   1954-04-26  Akira Kurosawa  Toshirō Mifune
# 1782  Crime,Drama,Mystery   1950-12-26  Akira Kurosawa  Toshirō Mifune

# %%
#new = pd.DataFrame(np.array(newDataFrameColumns.reshape(4,len(newDataFrameColumns))))
newDataFrameColumns = pd.DataFrame(newDataFrameColumns)
newDataFrameColumns2 = pd.DataFrame(newDataFrameColumns2)
combinedDataFrame = pd.concat([mainData,newDataFrameColumns], axis=1)
combinedDataFrame = pd.concat([combinedDataFrame,newDataFrameColumns2], axis=1)

# %%
combinedDataFrame
# Out:
#                                title                  original_title  \
# 0                          Toy Story                       Toy Story
# 1                            Jumanji                         Jumanji
# 2                  Waiting to Exhale               Waiting to Exhale
# 3                               Heat                            Heat
# 4                       Sudden Death                    Sudden Death
# 5                          GoldenEye                       GoldenEye
# 6             The American President          The American President
# 7                              Nixon                           Nixon
# 8                   Cutthroat Island                Cutthroat Island
# 9                             Casino                          Casino
# 10             Sense and Sensibility           Sense and Sensibility
# 11                        Four Rooms                      Four Rooms
# 12    Ace Ventura: When Nature Calls  Ace Ventura: When Nature Calls
# ...

# %%
combinedDataFrame.to_csv('newMainData.csv', index = False)
