# %%
import pandas as pd

# %%
# using the scraped data of actors, compute overall score (from the dff actors), 
# and add the 3 columns (wins, nominations, movie credits)to main dataset:

# %%
mergedData = pd.read_csv('mergedData.csv')
actorsWithScores = pd.read_csv('allActorsWithData.csv')

# %%
# mergedData['actorMovieCount'] = actorsWithScores[actorsWithScores['actorName'] == mergedData['actors']]
# actorsWithScores[actorsWithScores['actorName'] == mergedData['actors']]['actorAwardWins']
 
mergedData = mergedData.reset_index(drop=True)    
actorsWithScores = actorsWithScores.reset_index(drop=True)
    
mergedData['actorsMovieCounts'] = actorsWithScores[mergedData['actors'] == actorsWithScores['actorName']]
# function:
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-13c5edc7abe9> in <module>
#       7 actorsWithScores = actorsWithScores.reset_index(drop=True)
#       8
# ----> 9 mergedData['actorsMovieCounts'] = actorsWithScores[mergedData['actors'] == actorsWithScores['actorName']]
#      10 # function:
#
# ~/Desktop/Fall 2018 UW Classes/Data Sci - Info 370 HW/HW/recipe-scraper-env/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1188
#    1189         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1190             raise ValueError("Can only compare identically-labeled "
#    1191                              "Series objects")
#    1192
#
# ValueError: Can only compare identically-labeled Series objects

# %%
mergedData
# Out:
#        adult  belongs_to_collection    budget  \
# 0      False                   True  30000000
# 1      False                  False  65000000
# 2      False                   True         0
# 3      False                  False  16000000
# 4      False                   True         0
# 5      False                  False  60000000
# 6      False                  False  58000000
# 7      False                  False         0
# 8      False                  False  35000000
# 9      False                   True  58000000
# 10     False                  False  62000000
# 11     False                  False         0
# 12     False                   True         0
# 13     False                  False  44000000
# 14     False                  False  98000000
# 15     False                  False  52000000
# 16     False                  False  16500000
# 17     False                  False   4000000
# 18     False                   True  30000000
# ...
